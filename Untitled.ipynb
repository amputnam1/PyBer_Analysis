# %%
import matplotlib
matplotlib.__version__
# Out:
# '3.5.1'

# %%
conda install -c conda-forge matplotlib
# Out:
# ...
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.11.0
#   latest version: 4.12.0
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
#
# ## Package Plan ##
#
#   environment location: /Users/andreaputnam/opt/anaconda3
#
#   added / updated specs:
#     - matplotlib
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     certifi-2021.10.8          |   py39h6e9494a_1         145 KB  conda-forge
#     conda-4.12.0               |   py39h6e9494a_0         1.0 MB  conda-forge
#     matplotlib-3.5.1           |   py39h6e9494a_0           6 KB  conda-forge
#     python_abi-3.9             |           2_cp39           4 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         1.2 MB
#
# ...

# %%
conda update -n base -c defaults conda
# Out:
# ...
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /Users/andreaputnam/opt/anaconda3
#
#   added / updated specs:
#     - conda
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     astropy-5.0.2              |   py39h67323c0_0         6.6 MB
#     bottleneck-1.3.4           |   py39h67323c0_0         124 KB
#     conda-4.12.0               |   py39hecd8cb5_0        14.5 MB
#     conda-package-handling-1.8.0|   py39hca72f7f_0         1.5 MB
#     cython-0.29.28             |   py39he9d5cce_0         1.9 MB
#     jupyterlab-3.3.2           |     pyhd3eb1b0_0         3.6 MB
#     libllvm11-11.1.0           |       h46f1229_1        17.7 MB
#     llvmlite-0.38.0            |   py39h8346a28_0         236 KB
#     matplotlib-base-3.5.1      |   py39hfb0c5b7_1         5.7 MB
#     networkx-2.7.1             |     pyhd3eb1b0_0         1.3 MB
# ...
